# %% [markdown]
# This notebook is designed to complete one task, which is to get a DataFrame with all_ratio, developer as columns.
#
# After acquiring the two cvs files 'df_all_ratio_vs_developer.csv', it can then be used by Josh to plot images of all_ratio vs developer.

# %%
def convertJLtoDataFrame(fname='products_all.jl', key_list_used=['all_ratio','developer','genres']):
    '''
    Convert the raw data in .jl format to a DataFrame
    
    :fname: str name of a .jl file with data (defaults to 'products_all.jl' which is our data)
    
    :key_list_used: a list of strings that are the name of features in the data 
    (Defaults to just three features 'all_ratio, platform, genres' as a demo for our analysis)
    '''
    
    try:
        assert isinstance(fname, str) and '.jl' in fname  
    except AssertionError:
        print("fname is not a valid str name of a .jl file containing data!")
        
    try:
        assert isinstance(key_list_used, list)
    except AssertionError:
        print("key_list_used is not a valid list of genres")
        
    # Make the data into a list of all strings
    with open(fname,'r',encoding='utf8') as f:
        mylist = [line.rstrip('\n') for line in f]

    data_length = len(mylist)
    data_list = []

    # Convert the strings to dictionaries
    for i in mylist:
        d=json.loads(i)
        data_list.append(d)
        
    list_keys = list(data_list[0].keys())

    value_list_used = []
    key_list = []
    
    for i in key_list_used:
        key_list.append(i)
        value_list_used.append([])

    for i in data_list:
        # features w/o any values return None
        index = 0
        for key in key_list:
            value_list_used[index].append(i.get(key))
            index += 1

    # value_list_used = [value_list1,value_list2,value_list3]
    dic_used = dict(zip(key_list_used,value_list_used))

    # Convert to DataFrame
    df_used = pd.DataFrame(dic_used)
    
    # Return dataframe of the data from the .jl file
    return df_used

# %%
def parseRatioAndReviews(df):
    '''
    return a DataFrame with gaming apps which have an all_ratio
    '''
    

    df_with_all_ratio=df[df.all_ratio.str.contains('positive')]
    
    assert isinstance(df_with_all_ratio, pd.DataFrame)

    return df_with_all_ratio

# %%
def parseRatio_NreviewsAndDeveloper(df_with_all_ratio,fname='df_wordcount_100_most.csv'):
    '''return a DataFrame containing all_ratio 
    and developer only for the top 10'''
    
    assert isinstance(df_with_all_ratio, pd.DataFrame)
    
    list_all_ratio=[]
    list_N_reviews=[]
    
    for i in df_with_all_ratio.all_ratio:
        list_all_ratio.append(i.split()[0])
        list_N_reviews.append(i.split()[3])
    
    list_all_Developer=[]
    
    for i in df_with_all_ratio.developer:
        if type(i)==str:
            index1=i.find('Publisher')
            index2=i.find('Release')
            if index1!=-1:
                list_all_Developer.append(i[:index1])
                
            elif index2!=-1:
                list_all_Developer.append(i[:index2])
        else:
            list_all_Developer.append(None)
            
    dic_all_ratio_developer={'all_ratio':list_all_ratio,'developer':list_all_Developer}
    dic_Nreviews_developer={'#Reviews':list_N_reviews,'developer':list_all_Developer}
    df_all_ratio_developer=pd.DataFrame(dic_all_ratio_developer)
    df_Nreviews_developer=pd.DataFrame(dic_Nreviews_developer)
    return df_all_ratio_developer

# %%
import pandas as pd
import json
from IPython.display import display, HTML
from collections import Counter

def main():
    df_used = convertJLtoDataFrame()
    
    # Assert that a pandas DataFrame was returned
    assert isinstance(df_used, pd.DataFrame)
    
    print('DataFrame of data parsed from products_all.csv')
    df_used.to_csv('products_developer_counts.csv')
    display(df_used)
    
    df_with_all_ratio= parseRatioAndReviews(df_used)
    
    df_all_ratio_developer= parseRatio_NreviewsAndDeveloper(df_with_all_ratio)
    df_all_ratio_developer.to_csv('df_all_ratio_vs_developer.csv')
    
    display(df_all_ratio_developer)

# %%
if __name__ == "__main__":
    main()
# Out:
# DataFrame of data parsed from products_all.csv
#                                                all_ratio  \
# 0                                        No user reviews
# 1      78% of the 19 user reviews for this game are p...
# 2                                        No user reviews
# 3             Need more user reviews to generate a score
# 4                                        No user reviews
# 5                                        No user reviews
# 6                                        No user reviews
# 7                                        No user reviews
# 8                                        No user reviews
# 9                                        No user reviews
# 10                                       No user reviews
# 11                                       No user reviews
# 12                                       No user reviews
# 13                                       No user reviews
# 14                                       No user reviews
# 15                                       No user reviews
# 16            Need more user reviews to generate a score
# 17                                       No user reviews
# 18                                       No user reviews
# 19                                       No user reviews
# 20                                       No user reviews
# 21                                       No user reviews
# 22                                       No user reviews
# 23                                       No user reviews
# 24                                       No user reviews
# 25            Need more user reviews to generate a score
# 26                                       No user reviews
# 27                                       No user reviews
# 28                                       No user reviews
# 29            Need more user reviews to generate a score
# ...                                                  ...
# 39102                                    No user reviews
# 39103  86% of the 1,874 user reviews for this game ar...
# 39104  92% of the 28 user reviews for this game are p...
# 39105                                    No user reviews
# 39106         Need more user reviews to generate a score
# 39107                                    No user reviews
# 39108                                    No user reviews
# 39109                                    No user reviews
# 39110                                    No user reviews
# 39111                                    No user reviews
# 39112                                    No user reviews
# 39113                                    No user reviews
# 39114                                    No user reviews
# 39115                                    No user reviews
# 39116                                    No user reviews
# 39117                                    No user reviews
# 39118                                    No user reviews
# 39119                                    No user reviews
# 39120                                    No user reviews
# 39121                                    No user reviews
# 39122  58% of the 114 user reviews for this game are ...
# 39123  87% of the 7,959 user reviews for this game ar...
# 39124  77% of the 3,639 user reviews for this game ar...
# 39125                                    No user reviews
# 39126                                    No user reviews
# 39127                                    No user reviews
# 39128                                    No user reviews
# 39129                                    No user reviews
# 39130         Need more user reviews to generate a score
# 39131         Need more user reviews to generate a score
#
#                                                developer  \
# 0      Daily Magic ProductionsPublisher:Big Fish Game...
# 1      Pixelz GamesPublisher:CrytivoRelease Date: Apr...
# 2        EalsoftPublisher:EalsoftRelease Date: FALL 2018
# 3                                                   None
# 4      Mojiken StudioPublisher:Toge ProductionsReleas...
# 5              Magic Pixel Kft.Release Date: Nov 9, 2018
# 6              Magic Pixel Kft.Release Date: Nov 9, 2018
# 7      Nyan_FortPublisher:Nyan_FortRelease Date: Nov ...
# 8      Eren Aydin, Serhat YucekayaPublisher:Eren Aydi...
# 9      Platonic Game StudioPublisher:Something2Releas...
# 10     Ritual GamesPublisher:GrabTheGamesRelease Date...
# 11     Platonic Game StudioPublisher:Something2Releas...
# 12     Platonic Game StudioPublisher:Something2Releas...
# 13     Noble MuffinsPublisher:PlayWay S.A.Release Dat...
# 14     FinalBitPublisher:FinalBitRelease Date: Nov 9,...
# 15     AR GamingPublisher:AR GamingRelease Date: Sep ...
# 16     NailGun StudiosPublisher:NailGun StudiosReleas...
# 17     Bubble StudiosPublisher:Bubble StudiosRelease ...
# 18     Fractum InnovationsPublisher:Fractum Innovatio...
# 19     Mighty Papaya, ESATPublisher:ESATRelease Date:...
# 20     ESAT, Rocket BananaPublisher:ESATRelease Date:...
# 21     TriseumPublisher:TriseumFranchise:ARTéRelease ...
# 22     Fresh Red MinschePublisher:Fresh Red MinscheRe...
# 23     Utility SpectrumPublisher:Utility Spectrum Rel...
# 24        Sean MombourquettePublisher:Sean Mombourquette
# 25     Yuna StudioPublisher:Yuna StudioRelease Date: ...
# 26     SPARK GamesPublisher:SPARK GamesRelease Date: ...
# 27                                                  None
# 28     GoldenCrest GamesPublisher:GoldenCrest GamesRe...
# 29     Upturn GamesPublisher:Upturn GamesRelease Date...
# ...                                                  ...
# 39102               I.O.S. TeamRelease Date: Jan 1, 2002
# 39103      ValvePublisher:ValveRelease Date: May 1, 2003
# 39104  Spiderweb SoftwarePublisher:Spiderweb Software...
# 39105  FIRST_UKRAINIANPublisher:FIRST_UKRAINIANReleas...
# 39106  PolyGryph StudiosPublisher:PolyGryph StudiosRe...
# 39107                                               None
# 39108               ToastieLabsRelease Date: Nov 9, 2018
# 39109  Eren AydinPublisher:Eren AydinRelease Date: No...
# 39110  GGG GamesPublisher:Eternal SalvationRelease Da...
# 39111  GGG GamesPublisher:Eternal SalvationRelease Da...
# 39112  GGG GamesPublisher:Eternal SalvationRelease Da...
# 39113  SoftwavesPublisher:Softwaves Dist.Release Date...
# 39114  GGG GamesPublisher:Eternal SalvationRelease Da...
# 39115  CreaTeamPublisher:CreaTeamRelease Date: Nov 9,...
# 39116     SimFabricPublisher:SimFabricRelease Date: 2018
# 39117  SimFabricPublisher:SimFabricRelease Date: Q4 2018
# 39118  Space DriverPublisher:Space DriverRelease Date...
# 39119             SoftWeir Inc.Release Date: Nov 9, 2018
# 39120  Daybreak Game CompanyPublisher:Daybreak Game C...
# 39121  BirdwardsPublisher:BirdwardsRelease Date: Nov ...
# 39122  ToonTRAXX StudiosPublisher:Topware Interactive...
# 39123      ValvePublisher:ValveRelease Date: Mar 1, 2004
# 39124  ValvePublisher:ValveFranchise:Half-LifeRelease...
# 39125  OfficialCHPublisher:OfficialCHRelease Date: No...
# 39126  TomatoFantasyGamesPublisher:TomatoFantasyGames...
# 39127                                               None
# 39128  Granmust GamesPublisher:Granmust GamesRelease ...
# 39129  Jumbl Games, SnagBox StudioPublisher:Jumbl Gam...
# 39130  Dead Genre StudiosPublisher:Dead Genre Studios...
# 39131  Ghost Lord GamesPublisher:Ghost Lord GamesRele...
#
#                                                   genres
# 0                                    [Adventure, Casual]
# 1                          [Indie, Simulation, Strategy]
# 2                             [Adventure, Casual, Indie]
# 3                                                   None
# 4                             [Adventure, Casual, Indie]
# 5      [Action, Casual, Free to Play, Indie, Simulati...
# 6      [Action, Casual, Free to Play, Indie, Simulati...
# 7                                     [Adventure, Indie]
# 8                            [Action, Adventure, Casual]
# 9                                [Adventure, Indie, RPG]
# 10                            [Action, Adventure, Indie]
# 11                                                 [RPG]
# 12                                                 [RPG]
# 13                [Action, Adventure, Indie, Simulation]
# 14                   [Action, Casual, Indie, Simulation]
# 15                            [Action, Adventure, Indie]
# 16                                       [Casual, Indie]
# 17              [Action, Adventure, Indie, Early Access]
# 18                         [Action, Indie, Early Access]
# 19                            [Action, Adventure, Indie]
# 20                            [Action, Adventure, Indie]
# 21                    [Indie, RPG, Simulation, Strategy]
# 22                                       [Action, Indie]
# 23                                           [Utilities]
# 24                                       [Action, Indie]
# 25                         [Adventure, Casual, Strategy]
# 26                            [Action, Adventure, Indie]
# 27                                                  None
# 28     [Casual, Indie, Simulation, Sports, Strategy, ...
# 29                                [Casual, Free to Play]
# ...                                                  ...
# 39102                                           [Sports]
# 39103                                           [Action]
# 39104                             [Strategy, RPG, Indie]
# 39105        [Adventure, Casual, Indie, RPG, Simulation]
# 39106                                    [Indie, Sports]
# 39107                                               None
# 39108                      [Casual, Free to Play, Indie]
# 39109                        [Action, Adventure, Casual]
# 39110                  [Action, Casual, Indie, Strategy]
# 39111                  [Action, Casual, Indie, Strategy]
# 39112                                [Indie, Simulation]
# 39113                                    [Casual, Indie]
# 39114                            [Adventure, Indie, RPG]
# 39115                     [Adventure, Indie, Simulation]
# 39116  [Action, Adventure, Indie, Massively Multiplay...
# 39117                                [Indie, Simulation]
# 39118  [Adventure, Casual, Indie, Simulation, Strateg...
# 39119  [Animation &amp; Modeling, Design &amp; Illust...
# 39120  [Action, Adventure, Free to Play, Massively Mu...
# 39121                                    [Action, Indie]
# 39122                            [Action, Casual, Indie]
# 39123                                           [Action]
# 39124                                           [Action]
# 39125                                 [Adventure, Indie]
# 39126                              [Indie, Early Access]
# 39127                                               None
# 39128                                    [Casual, Indie]
# 39129   [Action, Adventure, Casual, Indie, Early Access]
# 39130                             [Indie, RPG, Strategy]
# 39131                            [Action, Casual, Indie]
#
# [39132 rows x 3 columns]
#       all_ratio                       developer
# 0           78%                    Pixelz Games
# 1           83%                 Outerlight Ltd.
# 2           79%                         Egosoft
# 3           73%                         Egosoft
# 4           57%                  Strategy First
# 5           90%           Introversion Software
# 6           75%                        Techland
# 7          100%              PopCap Games, Inc.
# 8           85%              PopCap Games, Inc.
# 9           77%              PopCap Games, Inc.
# 10          70%              PopCap Games, Inc.
# 11          91%              PopCap Games, Inc.
# 12          92%              PopCap Games, Inc.
# 13          78%                    GlyphX Games
# 14          83%           Introversion Software
# 15          96%         Double Fine Productions
# 16          93%                   Infinity Ward
# 17          90%      Infinity Ward, Aspyr (Mac)
# 18          84%             Gray Matter Studios
# 19          67%           Malfador Machinations
# 20          43%                          PopTop
# 21          89%                   Firaxis Games
# 22          92%                   Firaxis Games
# 23          67%                       Sonalysts
# 24          80%                       Sonalysts
# 25          86%                  Arkane Studios
# 26          75%  FireFly Studios, Firaxis Games
# 27          87%                   Firaxis Games
# 28          91%                          Funcom
# 29          71%                          PopTop
# ...         ...                             ...
# 16691      100%             OhNoo Studio, Smile
# 16692       90%              PopCap Games, Inc.
# 16693       87%              PopCap Games, Inc.
# 16694       92%              PopCap Games, Inc.
# 16695       86%              PopCap Games, Inc.
# 16696       90%              PopCap Games, Inc.
# 16697       93%              PopCap Games, Inc.
# 16698       96%              PopCap Games, Inc.
# 16699       95%              PopCap Games, Inc.
# 16700       92%              PopCap Games, Inc.
# 16701       88%             Relic Entertainment
# 16702      100%                     Konfa Games
# 16703       63%                           Fazan
# 16704       89%              Klei Entertainment
# 16705       86%           Ballistic Interactive
# 16706       81%             Stainless Games Ltd
# 16707       95%                           Valve
# 16708       81%                           Valve
# 16709       94%                Gearbox Software
# 16710       77%                           Valve
# 16711       96%                           Valve
# 16712       84%                   Piranha Bytes
# 16713       81%                           Valve
# 16714       89%                Gearbox Software
# 16715       93%              Spiderweb Software
# 16716       86%                           Valve
# 16717       92%              Spiderweb Software
# 16718       58%               ToonTRAXX Studios
# 16719       87%                           Valve
# 16720       77%                           Valve
#
# [16721 rows x 2 columns]
