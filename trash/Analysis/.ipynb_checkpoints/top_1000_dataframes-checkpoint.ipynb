# %% [markdown]
# Author: Joshua Williams
#
# The purpose of this code is to generate csv files that quantify the appearence of certain attributes within our top 1000 well recieved games (data4.csv). Its purpose is also to make sure that these csv files are easily convertible to Chartify charts for plots_for_top_1000.ipynb.

# %%
def display_csv(fname):
    '''
    Function to display a dataframe from a file name (this file must have the .csv extension!)
    fname: the name of a csv to be displayed 
    '''
    import pandas as pd
    import json
    from IPython.display import display, HTML

    assert isinstance(fname, str) and '.csv' in fname, 'Input is not a valid name of a csv file'
    
    df = pd.read_csv(fname)
    display(df)
display_csv(fname='dataframe_1000.csv')
# Out:
#      Unnamed: 0                                   app_name  \
# 0           861                                     Dota 2
# 1         20992              PLAYERUNKNOWN'S BATTLEGROUNDS
# 2         24785                                   Unturned
# 3         38962                                Garry's Mod
# 4           371                                   Terraria
# 5         10814                                  Paladins®
# 6          2530                             Rocket League®
# 7          2328                  The Witcher® 3: Wild Hunt
# 8         38060                              Left 4 Dead 2
# 9         19485                                       H1Z1
# 10          767                     Euro Truck Simulator 2
# 11         7805                      ARK: Survival Evolved
# 12         8305                 Doki Doki Literature Club!
# 13        37467                                   Portal 2
# 14        23696                                  Robocraft
# 15        33286                                  Undertale
# 16        37616                Sid Meier's Civilization® V
# 17        36670                                War Thunder
# 18        20399                                 Subnautica
# 19        22514                                 Brawlhalla
# 20         1084                                 Insurgency
# 21         5090                          Heroes & Generals
# 22          950                              Path of Exile
# 23        39097                             Counter-Strike
# 24        31544                      Don't Starve Together
# 25        37930                     Mount & Blade: Warband
# 26         5032                           Wallpaper Engine
# 27        30569                                  Starbound
# 28        36536                       No More Room in Hell
# 29        33790                                      Trove
# ..          ...                                        ...
# 970        1430              Deponia: The Complete Journey
# 971       35701                         EVGA Precision XOC
# 972       20208                                     Delver
# 973       37695                   The Guild II Renaissance
# 974       12188                                 Green Hell
# 975         434                              Costume Quest
# 976       11138                  Football, Tactics & Glory
# 977       33362  Renowned Explorers: International Society
# 978         918       Euro Truck Simulator 2 - Going East!
# 979         218                                   Altitude
# 980       32248                         Tales of Symphonia
# 981        9828                                   Dungreed
# 982        1316                                  ibb & obb
# 983       20101                                   GUNS UP!
# 984       27969                            Angels of Death
# 985        1132                            Infested Planet
# 986       19953                              Dragon Knight
# 987        2064                    Tormentum - Dark Sorrow
# 988       10982                                    Wrecked
# 989        2817                           Sakura Swim Club
# 990       35733    Magic 2015 - Duels of the Planeswalkers
# 991       28157                     TY the Tasmanian Tiger
# 992       25090                            Colony Survival
# 993       34338                       Controller Companion
# 994        4902                              Trick & Treat
# 995       29087                          Rusty Lake: Roots
# 996         186   Tom Clancy's Splinter Cell Chaos Theory®
# 997       33473  Rocket League® - Supersonic Fury DLC Pack
# 998        3451                            My Name is Mayo
# 999       21233           ARK: Aberration - Expansion Pack
#
#                                          title        id  \
# 0                                          NaN     570.0
# 1                PLAYERUNKNOWN'S BATTLEGROUNDS  578080.0
# 2                                     Unturned  304930.0
# 3                                  Garry's Mod    4000.0
# 4                                     Terraria  105600.0
# 5                                    Paladins®  444090.0
# 6                               Rocket League®  252950.0
# 20   90% of the 68,400 user reviews for this game a...
# 21   65% of the 94,493 user reviews for this game a...
# 22   91% of the 64,588 user reviews for this game a...
# 23   96% of the 59,056 user reviews for this game a...
# 24   96% of the 57,550 user reviews for this game a...
# 25   97% of the 54,004 user reviews for this game a...
# 26   96% of the 51,660 user reviews for this softwa...
# 27   90% of the 54,432 user reviews for this game a...
# 28   89% of the 52,722 user reviews for this game a...
# 29   77% of the 59,505 user reviews for this game a...
# ..                                                 ...
# 970  88% of the 1,751 user reviews for this game ar...
# 971  74% of the 2,070 user reviews for this softwar...
# 972  88% of the 1,736 user reviews for this game ar...
# 973  79% of the 1,932 user reviews for this game ar...
# 974  84% of the 1,817 user reviews for this game ar...
# 975  94% of the 1,623 user reviews for this game ar...
# 976  90% of the 1,694 user reviews for this game ar...
# 977  92% of the 1,656 user reviews for this game ar...
# 978  93% of the 1,637 user reviews for this game ar...
# 979  92% of the 1,653 user reviews for this game ar...
# 980  81% of the 1,871 user reviews for this game ar...
# 981  87% of the 1,741 user reviews for this game ar...
# 982  93% of the 1,628 user reviews for this game ar...
# 983  62% of the 2,436 user reviews for this game ar...
# 984  94% of the 1,605 user reviews for this game ar...
# 985  94% of the 1,601 user reviews for this game ar...
# 986  78% of the 1,920 user reviews for this game ar...
# 987  93% of the 1,610 user reviews for this game ar...
# 988  77% of the 1,944 user reviews for this game ar...
# 989  86% of the 1,739 user reviews for this game ar...
# 990  44% of the 3,401 user reviews for this game ar...
# 991  98% of the 1,524 user reviews for this game ar...
# 992  84% of the 1,769 user reviews for this game ar...
# 993  92% of the 1,615 user reviews for this softwar...
# 994  96% of the 1,547 user reviews for this game ar...
# 995  95% of the 1,563 user reviews for this game ar...
# 996  92% of the 1,612 user reviews for this game ar...
# 997  95% of the 1,560 user reviews for this game ar...
# 998  82% of the 1,807 user reviews for this game ar...
# 999  73% of the 2,029 user reviews for this game ar...
#
#                                                 genres  \
# 0                                                  NaN
# 1     ['Action', 'Adventure', 'Massively Multiplayer']
# 2    ['Action', 'Adventure', 'Casual', 'Free to Pla...
# 3                              ['Indie', 'Simulation']
# 4              ['Action', 'Adventure', 'Indie', 'RPG']
# 5                           ['Action', 'Free to Play']
# 6              ['Action', 'Indie', 'Racing', 'Sports']
# 7                                              ['RPG']
# 8                                           ['Action']
# 9    ['Action', 'Adventure', 'Free to Play', 'Massi...
# 10                             ['Indie', 'Simulation']
# 11   ['Action', 'Adventure', 'Indie', 'Massively Mu...
# 12                 ['Casual', 'Free to Play', 'Indie']
# 13                             ['Action', 'Adventure']
# 14   ['Action', 'Free to Play', 'Indie', 'Massively...
# 15                                    ['Indie', 'RPG']
# 16                                        ['Strategy']
# 17                                                 NaN
# 18                                                 NaN
# 19                 ['Action', 'Free to Play', 'Indie']
# 20                     ['Action', 'Indie', 'Strategy']
# 21   ['Action', 'Free to Play', 'Indie', 'Massively...
# 22   ['Action', 'Adventure', 'Free to Play', 'Indie...
# 23                                          ['Action']
# 24                ['Adventure', 'Indie', 'Simulation']
# 25                                   ['Action', 'RPG']
# 26   ['Animation &amp; Modeling', 'Design &amp; Ill...
# 27   ['Action', 'Adventure', 'Casual', 'Indie', 'RPG']
# 28                 ['Action', 'Free to Play', 'Indie']
# 29   ['Action', 'Adventure', 'Casual', 'Free to Pla...
# ..                                                 ...
# 970                                      ['Adventure']
# 971                                      ['Utilities']
# 972            ['Action', 'Adventure', 'Indie', 'RPG']
# 973                         ['Simulation', 'Strategy']
# 974            ['Indie', 'Simulation', 'Early Access']
# 975                     ['Adventure', 'Casual', 'RPG']
# 976      ['Indie', 'Simulation', 'Sports', 'Strategy']
# 977          ['Adventure', 'Indie', 'RPG', 'Strategy']
# 978                            ['Indie', 'Simulation']
# 979                ['Action', 'Free to Play', 'Indie']
# 980                                            ['RPG']
# 981                                ['Action', 'Indie']
# 982                   ['Action', 'Adventure', 'Indie']
# 983   ['Action', 'Casual', 'Free to Play', 'Strategy']
# 984                      ['Adventure', 'Indie', 'RPG']
# 985                    ['Action', 'Indie', 'Strategy']
# 986            ['Action', 'Adventure', 'Indie', 'RPG']
# 987                   ['Adventure', 'Casual', 'Indie']
# 988  ['Action', 'Free to Play', 'Massively Multipla...
# 989                                ['Casual', 'Indie']
# 990                                       ['Strategy']
# 991                   ['Action', 'Adventure', 'Indie']
# 992  ['Action', 'Adventure', 'Indie', 'Strategy', '...
# 993                                      ['Utilities']
# 994   ['Adventure', 'Casual', 'Free to Play', 'Indie']
# 995                             ['Adventure', 'Indie']
# 996                                         ['Action']
# 997            ['Action', 'Indie', 'Racing', 'Sports']
# 998                           ['Casual', 'Simulation']
# 999  ['Action', 'Adventure', 'Indie', 'Massively Mu...
#
#                                                  specs  \
# 0    ['Multi-player', 'Co-op', 'Steam Trading Cards...
# 1     ['Multi-player', 'Online Multi-Player', 'Stats']
# 2    ['Single-player', 'Online Multi-Player', 'Onli...
# 3    ['Single-player', 'Multi-player', 'Co-op', 'Cr...
# 4    ['Single-player', 'Multi-player', 'Online Mult...
# 5    ['Multi-player', 'Online Multi-Player', 'Steam...
# 6    ['Single-player', 'Multi-player', 'Co-op', 'Sh...
# 7    ['Single-player', 'Steam Achievements', 'Full ...
# 8    ['Single-player', 'Multi-player', 'Co-op', 'St...
# 9    ['Multi-player', 'Online Multi-Player', 'In-Ap...
# 10   ['Single-player', 'Steam Achievements', 'Steam...
# 11   ['Single-player', 'Multi-player', 'MMO', 'Co-o...
# 12                                   ['Single-player']
# 13   ['Single-player', 'Co-op', 'Steam Achievements...
# 14   ['Multi-player', 'Online Multi-Player', 'MMO',...
# 15            ['Single-player', 'Steam Trading Cards']
# 16   ['Single-player', 'Multi-player', 'Steam Achie...
# 17   ['Single-player', 'MMO', 'Co-op', 'Cross-Platf...
# 18   ['Single-player', 'Steam Achievements', 'Full ...
# 19   ['Single-player', 'Multi-player', 'Online Mult...
# 20   ['Multi-player', 'Co-op', 'Cross-Platform Mult...
# 21   ['Multi-player', 'Online Multi-Player', 'MMO',...
# 22   ['Single-player', 'Multi-player', 'Online Mult...
# 23   ['Multi-player', 'Online Multi-Player', 'Local...
# 24   ['Single-player', 'Multi-player', 'Co-op', 'Cr...
# 25   ['Single-player', 'Multi-player', 'Steam Achie...
# 26   ['Steam Achievements', 'Steam Trading Cards', ...
# 27   ['Single-player', 'Multi-player', 'Online Mult...
# 28   ['Multi-player', 'Co-op', 'Cross-Platform Mult...
# 29   ['Online Multi-Player', 'MMO', 'Co-op', 'Steam...
# ..                                                 ...
# 970  ['Single-player', 'Steam Achievements', 'Steam...
# 971            ['Single-player', 'Steam Achievements']
# 972  ['Single-player', 'Steam Achievements', 'Full ...
# 973                                  ['Single-player']
# 974                                  ['Single-player']
# 975  ['Single-player', 'Steam Achievements', 'Steam...
# 976  ['Single-player', 'Multi-player', 'Steam Achie...
# 977  ['Single-player', 'Steam Achievements', 'Steam...
# 978  ['Single-player', 'Downloadable Content', 'Ste...
# 979  ['Single-player', 'Multi-player', 'Cross-Platf...
# 980  ['Single-player', 'Steam Achievements', 'Full ...
# 981  ['Single-player', 'Steam Achievements', 'Full ...
# 982  ['Multi-player', 'Co-op', 'Shared/Split Screen...
# 983  ['Single-player', 'Online Multi-Player', 'Cros...
# 984  ['Single-player', 'Steam Trading Cards', 'Part...
# 985  ['Single-player', 'Steam Achievements', 'Steam...
# 986  ['Single-player', 'Steam Achievements', 'Full ...
# 987  ['Single-player', 'Steam Achievements', 'Steam...
# 988  ['Multi-player', 'Online Multi-Player', 'Cross...
# 989           ['Single-player', 'Steam Trading Cards']
# 990  ['Single-player', 'Multi-player', 'Steam Achie...
# 991  ['Single-player', 'Steam Achievements', 'Full ...
# 992  ['Single-player', 'Multi-player', 'Online Mult...
# 993      ['Full controller support', 'Steam Workshop']
# 994  ['Single-player', 'Steam Achievements', 'Steam...
# 995  ['Single-player', 'Steam Achievements', 'Steam...
# 996                                  ['Single-player']
# 997  ['Single-player', 'Multi-player', 'Co-op', 'Sh...
# 998  ['Single-player', 'Steam Achievements', 'Steam...
# 999  ['Single-player', 'Multi-player', 'MMO', 'Co-o...
#
#                        platform  \
# 0            Linux,Mac,Windows,
# 1                      Windows,
# 2            Linux,Mac,Windows,
# 3            Linux,Mac,Windows,
# 4            Linux,Mac,Windows,
# 5                      Windows,
# 6            Linux,Mac,Windows,
# 7                      Windows,
# 8            Linux,Mac,Windows,
# 9                      Windows,
# 10           Linux,Mac,Windows,
# 11           Linux,Mac,Windows,
# 12                 Mac,Windows,
# 13           Linux,Mac,Windows,
# 14           Linux,Mac,Windows,
# 15           Linux,Mac,Windows,
# 16   SteamOS,Linux,Mac,Windows,
# 17   SteamOS,Linux,Mac,Windows,
# 18                 Mac,Windows,
# 19                 Mac,Windows,
# 20           Linux,Mac,Windows,
# 21                     Windows,
# 22                     Windows,
# 23           Linux,Mac,Windows,
# 24           Linux,Mac,Windows,
# 25           Linux,Mac,Windows,
# 26                     Windows,
# 27           Linux,Mac,Windows,
# 28           Linux,Mac,Windows,
# 29                 Mac,Windows,
# ..                          ...
# 970          Linux,Mac,Windows,
# 971                    Windows,
# 972          Linux,Mac,Windows,
# 973                    Windows,
# 974                    Windows,
# 975          Linux,Mac,Windows,
# 976                    Windows,
# 977          Linux,Mac,Windows,
# 978          Linux,Mac,Windows,
# 979          Linux,Mac,Windows,
# 980                    Windows,
# 981                Mac,Windows,
# 982          Linux,Mac,Windows,
# 983                    Windows,
# 984                    Windows,
# 985                Mac,Windows,
# 986                Mac,Windows,
# 987                Mac,Windows,
# 988          Linux,Mac,Windows,
# 989          Linux,Mac,Windows,
# 990                    Windows,
# 991                    Windows,
# 992  SteamOS,Linux,Mac,Windows,
# 993                    Windows,
# 994                    Windows,
# 995                Mac,Windows,
# 996                    Windows,
# 997          Linux,Mac,Windows,
# 998                    Windows,
# 999          Linux,Mac,Windows,
#
#                                              developer  \
# 0                                                  NaN
# 1    PUBG CorporationPublisher:PUBG CorporationRele...
# 2    Smartly Dressed GamesPublisher:Smartly Dressed...
# 3    Facepunch StudiosPublisher:ValveRelease Date: ...
# 4    Re-LogicPublisher:Re-LogicRelease Date: May 16...
# 5    Evil Mojo GamesPublisher:Hi-Rez StudiosRelease...
# 6    Psyonix, Inc.Publisher:Psyonix, Inc.Release Da...
# 7    CD PROJEKT REDPublisher:CD PROJEKT REDRelease ...
# 8       ValvePublisher:ValveRelease Date: Nov 16, 2009
# 9    Daybreak Game Company, NantGPublisher:Daybreak...
# 10   SCS SoftwarePublisher:SCS SoftwareRelease Date...
# 11   Studio Wildcard, Instinct Games, Efecto Studio...
# 12   Team SalvatoPublisher:Team SalvatoRelease Date...
# 13      ValvePublisher:ValveRelease Date: Apr 18, 2011
# 14   FreejamPublisher:FreejamRelease Date: Aug 24, ...
# 15   tobyfoxPublisher:tobyfoxRelease Date: Sep 15, ...
# 16   Firaxis Games, Aspyr (Mac), Aspyr (Linux)Publi...
# 17                                                 NaN
# 18                                                 NaN
# 19   Blue Mammoth GamesPublisher:UbisoftRelease Dat...
# 20   New World InteractivePublisher:New World Inter...
# 21   RETO MOTOPublisher:RETO MOTORelease Date: Oct ...
# 22   Grinding Gear GamesPublisher:Grinding Gear Gam...
# 23       ValvePublisher:ValveRelease Date: Nov 1, 2000
# 24   Klei EntertainmentPublisher:Klei Entertainment...
# 25   TaleWorlds EntertainmentPublisher:TaleWorlds E...
# 26   Kristjan SkuttaPublisher:Kristjan SkuttaReleas...
# 27   ChucklefishPublisher:ChucklefishRelease Date: ...
# 28   No More Room in Hell TeamPublisher:Lever Games...
# 29   Trion WorldsPublisher:Trion WorldsRelease Date...
# ..                                                 ...
# 970  Daedalic EntertainmentPublisher:Daedalic Enter...
# 971       EVGAPublisher:EVGARelease Date: Sep 19, 2014
# 972        Priority InterruptRelease Date: Feb 1, 2018
# 973  Rune ForgePublisher:THQ NordicFranchise:The Gu...
# 974  Creepy JarPublisher:Creepy JarRelease Date: Au...
# 975  Double Fine ProductionsPublisher:Double Fine P...
# 976  CreoteamPublisher:CreoteamRelease Date: Jun 1,...
# 977  Abbey GamesPublisher:Abbey GamesRelease Date: ...
# 978  SCS SoftwarePublisher:SCS SoftwareRelease Date...
# 979  Nimbly GamesPublisher:Nimbly GamesRelease Date...
# 980  BANDAI NAMCO Entertainment Inc.Publisher:BANDA...
# 981  TEAM HORAYPublisher:TEAM HORAYRelease Date: Fe...
# 982  Sparpweed, CodegluePublisher:SparpweedRelease ...
# 983  Valkyrie Entertainment, LLCPublisher:PlayStati...
# 984  Vaka Game Magazine, Makoto SanadaPublisher:Vak...
# 985  Rocket Bear GamesPublisher:Rocket Bear GamesRe...
# 986  D.K StudioPublisher:Paradise ProjectRelease Da...
# 987  OhNoo StudioPublisher:OhNoo StudioRelease Date...
# 988  Marco AmadeiPublisher:Corvostudio di Amadei Ma...
# 989  Winged CloudPublisher:Winged CloudRelease Date...
# 990  Stainless GamesPublisher:Wizards of the CoastR...
# 991  Krome StudiosPublisher:Krome StudiosRelease Da...
# 992   PiplizPublisher:PiplizRelease Date: Jun 16, 2017
# 993  Koga Tech LimitedPublisher:Koga Tech LimitedRe...
# 994  RabbitonPublisher:RabbitonRelease Date: Sep 26...
# 995  Rusty LakePublisher:Rusty LakeRelease Date: Oc...
# 996  Ubisoft MontrealPublisher:UbisoftRelease Date:...
# 997  Psyonix, Inc.Publisher:Psyonix, Inc.Release Da...
# 998  Green Lava StudiosPublisher:Green Lava Studios...
# 999  Studio Wildcard, Instinct Games, Efecto Studio...
#
#                                              Developer  \
# 0                                                  NaN
# 1                                     PUBG Corporation
# 2                                Smartly Dressed Games
# 3                                    Facepunch Studios
# 4                                             Re Logic
# 5                                      Evil Mojo Games
# 6                                          Psyonix Inc
# 7                                       CD PROJEKT RED
# 8                                                Valve
# 9                          Daybreak Game Company NantG
# 10                                        SCS Software
# 11   Studio Wildcard Instinct Games Efecto Studios ...
# 12                                        Team Salvato
# 13                                               Valve
# 14                                             Freejam
# 15                                             tobyfox
# 16                 Firaxis Games Aspyr Mac Aspyr Linux
# 17                                                 NaN
# 18                                                 NaN
# 19                                  Blue Mammoth Games
# 20                               New World Interactive
# 21                                           RETO MOTO
# 22                                 Grinding Gear Games
# 23                                               Valve
# 24                                  Klei Entertainment
# 25                            TaleWorlds Entertainment
# 26                                     Kristjan Skutta
# 27                                         Chucklefish
# 28                           No More Room in Hell Team
# 29                                        Trion Worlds
# ..                                                 ...
# 970                             Daedalic Entertainment
# 971                                               EVGA
# 972                                                NaN
# 973                                         Rune Forge
# 974                                         Creepy Jar
# 975                            Double Fine Productions
# 976                                           Creoteam
# 977                                        Abbey Games
# 978                                       SCS Software
# 979                                       Nimbly Games
# 980                     BANDAI NAMCO Entertainment Inc
# 981                                         TEAM HORAY
# 982                                 Sparpweed Codeglue
# 983                         Valkyrie Entertainment LLC
# 984                   Vaka Game Magazine Makoto Sanada
# 985                                  Rocket Bear Games
# 986                                         D K Studio
# 987                                       OhNoo Studio
# 988                                       Marco Amadei
# 989                                       Winged Cloud
# 990                                    Stainless Games
# 991                                      Krome Studios
# 992                                             Pipliz
# 993                                  Koga Tech Limited
# 994                                           Rabbiton
# 995                                         Rusty Lake
# 996                                   Ubisoft Montreal
# 997                                        Psyonix Inc
# 998                                 Green Lava Studios
# 999                                                NaN
#
# 10          106896.0                    11
# 11          105096.0                    12
# 12          100163.0                    13
# 13           91603.0                    14
# 14           79068.0                    15
# 15           78027.0                    16
# 16           76288.0                    17
# 17           76267.0                    18
# 18           68159.0                    19
# 19           63572.0                    20
# 20           61560.0                    21
# 21           61420.0                    22
# 22           58775.0                    23
# 23           56694.0                    24
# 24           55248.0                    25
# 25           52384.0                    26
# 26           49594.0                    27
# 27           48989.0                    28
# 28           46923.0                    29
# 29           45819.0                    30
# ..               ...                   ...
# 970           1541.0                   970
# 971           1532.0                   972
# 972           1528.0                   973
# 973           1526.0                   974
# 974           1526.0                   974
# 975           1526.0                   974
# 976           1525.0                   977
# 977           1524.0                   978
# 978           1522.0                   979
# 979           1521.0                   980
# 980           1516.0                   981
# 981           1515.0                   982
# 982           1514.0                   983
# 983           1510.0                   984
# 984           1509.0                   985
# 985           1505.0                   986
# 986           1498.0                   987
# 987           1497.0                   988
# 988           1497.0                   988
# 989           1496.0                   990
# 990           1496.0                   990
# 991           1494.0                   992
# 992           1486.0                   993
# 993           1486.0                   993
# 994           1485.0                   995
# 995           1485.0                   995
# 996           1483.0                   997
# 997           1482.0                   998
# 998           1482.0                   998
# 999           1481.0                  1000
#
# [1000 rows x 15 columns]

# %%
def countPlatform(fname='data4.csv'):
    '''
    Function to count how many games support each platform (Windows, Mac, Linux)
    
    (fname): A string name of a dataframe
    '''
    import pandas as pd
    assert isinstance(fname, str) and '.csv' in fname, 'fname is not a string name of a .csv file'
    
    df = pd.read_csv(fname)
    
    platforms = df['platform'].tolist()
    platform_dict = {}
    
    for platform_string in platforms:
        
        platform_list = list(platform_string.split(','))
        platform_list.remove('')
        
        index = 0
        while index < len(platform_list):
            if platform_list[index] in platform_dict.keys():
                platform_dict[platform_list[index]] += 1
            else:
                platform_dict[platform_list[index]] = 1
            index += 1
        
    platform_df = pd.DataFrame(platform_dict, index=["count"])

    return platform_df

# %%
def countQuantity(fname='data4.csv', col_name=''):
    '''
    Function to count the quantity of appearencesof an attribute in a specfied column
    NOTE: This function is geared toward columns that have list type items
    
    (fname): A string name of a dataframe
    (col_name): string name of a column in the dataframe
    '''
    import pandas as pd
    import ast
    assert isinstance(fname, str) and '.csv' in fname, 'fname is not a string name of a .csv file'
    assert isinstance(col_name, str), 'col_name is not of string type'
    
    df = pd.read_csv(fname)
    
    assert col_name in df, 'Specified column name does not exist in the specified dataframe!'
    
    col_val_list = df[col_name].tolist()
    column_dict = {}
    
    for col_val in col_val_list:
        if pd.isnull(col_val):
            continue
        
        # Converts string of a list to a list
        col_val = ast.literal_eval(col_val)
        
        for val in list(col_val):
            if val in column_dict.keys():
                column_dict[val] += 1
            else:
                column_dict[val] = 1
        
    column_df = pd.DataFrame(column_dict, index=["count"])

    column_df = column_df.sort_values('count', axis=1, ascending=False)
    
    return column_df

# %%
def countPublisher(fname='data4.csv'):
    '''
    Function to count the quantity of appearences of a developer in our data
    
    (fname): A string name of a dataframe
    '''
    import pandas as pd
    import re
    assert isinstance(fname, str) and '.csv' in fname, 'fname is not a string name of a .csv file'
    
    df = pd.read_csv(fname)
    
    developers = df['developer'].tolist()
    developer_dict = {}
    
    for developer in developers:
        # Get the publisher name between these two strings
        start = 'Publisher:'
        end = 'Release Date:'
        
        if pd.isnull(developer):
            continue
        
        developer = developer[developer.find(start)+len(start):developer.find(end)]
        
        if developer in developer_dict.keys():
            developer_dict[developer] += 1
        else:
            developer_dict[developer] = 1
        
    developer_df = pd.DataFrame(developer_dict, index=["count"])
    developer_df = developer_df.sort_values('count', axis=1, ascending=False)
    
    return developer_df

# %%
def main():
    '''
    Author: Joshua Williams
    '''
    import pandas as pd
    
    # Get platform dataframe
    df_platform = countPlatform()
    # Save to csv
    #df_platform.to_csv('platform_count.csv')
    print('Platform Dataframe')
    display_csv('platform_count.csv')
    
    
    # Get specs dataframe
    df_specs = countQuantity(col_name='specs')
    # Save to csv
    #df_specs.to_csv('specs_count.csv')
    print('Specs Dataframe')
    display_csv('specs_count.csv')
    
              
    # Get genres dataframe
    df_genres = countQuantity(col_name='genres')
    # Save to csv
    #df_genres.to_csv('genres_count.csv')            
    print('Genres Dataframe')
    display_csv('genres_count.csv')
    
    
    # Get developers dataframe
    df_developers = countDeveloper()
    # Save to csv
    #df_developers.to_csv('developers_count.csv')
    print('Publisher Dataframe')
    display_csv('developers_count.csv')
    
if __name__ == "__main__":
    main()
# Out:
# Platform Dataframe
#   Unnamed: 0  Linux  Mac  Windows  SteamOS
# 0      count    336  465     1000       41
# Specs Dataframe
#   Unnamed: 0  Single-player  Steam Achievements  Steam Trading Cards  \
# 0      count            911                 680                  547
#
#    Steam Cloud  Multi-player  Full controller support  \
# 0          437           286                      257
#
#    Partial Controller Support  Steam Leaderboards  Co-op         ...          \
# 0                         209                 190    138         ...
#
#    Windows Mixed Reality  Keyboard / Mouse  Gamepad  Valve Anti-Cheat enabled  \
# 0                     18                15       13                        11
#
#    Commentary available  SteamVR Collectibles  Includes Source SDK  \
# 0                    10                     7                    5
#
#    Steam Turn Notifications  Mods  Mods (require HL2)
# 0                         4     1                   1
#
# [1 rows x 40 columns]
# Genres Dataframe
#   Unnamed: 0  Indie  Action  Adventure  Strategy  RPG  Casual  Simulation  \
# 0      count    619     428        335       228  213     194         189
#
#    Free to Play  Early Access        ...         Sports  Racing  Utilities  \
# 0           131            69        ...             42      42          7
#
#    Animation &amp; Modeling  Design &amp; Illustration  Video Production  \
# 0                         3                          2                 1
#
#    Education  Software Training  Game Development  Audio Production
# 0          1                  1                 1                 1
#
# [1 rows x 21 columns]
# Developers Dataframe
#   Unnamed: 0  Paradox Interactive  Daedalic Entertainment  Devolver Digital  \
# 0      count                   18                      13                12
#
#    Ubisoft  SEGA  Electronic Arts  SCS Software  Sekai Project  AGM PLAYISM  \
# 0       12    10                8             8              8            7
#
#       ...      Abrakam SA  DANKIE  Screeps  The Working Parts  \
# 0     ...               1       1        1                  1
#
#    Frogsong Studios AB  Hangover Cat Purrroduction  Titans  Lucky Pause  \
# 0                    1                           1       1            1
#
#    ZuoBuLaiGame  Pirotexnik
# 0             1           1
#
# [1 rows x 669 columns]
